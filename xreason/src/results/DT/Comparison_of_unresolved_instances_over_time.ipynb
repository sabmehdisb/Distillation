# %%
import json

import json
dataset="biodegradation_0_default"
myfile = dataset+".json"

with open(myfile, 'r') as file_json:
    data_read = json.load(file_json)

# %%
time_rectification=data_read["time_rectification_for_each_rule"]
elapsed_time_specific_reason_and_different_instances_for_all_trees=data_read["elapsed_time_specific_reason_and_different_instances_for_all_trees"]
elapsed_time_sufficient_reason_for_all_trees_after_correction=data_read["elapsed_time_sufficient_reason_for_all_trees_after_correction"]
number_of_noued_BT=data_read["bt_model.n_nodes"]
print("number_of_noued_BT",number_of_noued_BT)
# Out:
# number_of_noued_BT 2222

# %%
import statistics
mean_size = []
for i in range(max(len(sublist) for sublist in elapsed_time_sufficient_reason_for_all_trees_after_correction)):
    position_values = [sublist[i] for sublist in elapsed_time_sufficient_reason_for_all_trees_after_correction if i < len(sublist)]
    mean_value = statistics.mean(position_values)
    mean_size.append(mean_value)
temps_cumuile_rectification = [sum(sublist) for sublist in time_rectification]
average_rectification = sum(temps_cumuile_rectification) / len(temps_cumuile_rectification)
temps_avg_elapsed_time_sufficient_reason_for_all_trees_after_correction = [sum(sublist) / len(sublist)  for sublist in elapsed_time_sufficient_reason_for_all_trees_after_correction]
average_elapsed_time_sufficient_reason_for_all_trees_after_correction = sum(temps_avg_elapsed_time_sufficient_reason_for_all_trees_after_correction) / len(temps_avg_elapsed_time_sufficient_reason_for_all_trees_after_correction)
std_time_sufficient_reason= statistics.stdev(temps_avg_elapsed_time_sufficient_reason_for_all_trees_after_correction)
time_compilation = [a + b for a, b in zip(elapsed_time_specific_reason_and_different_instances_for_all_trees,
                                         temps_cumuile_rectification)]
average_time_compilation = sum(time_compilation) / len(time_compilation)
std_time_compilation = statistics.stdev(time_compilation)
#print("average_rectification and temps_cumuile_rectification",average_rectification,temps_cumuile_rectification)
#print("elapsed_time_specific_reason_and_different_instances_for_all_trees",elapsed_time_specific_reason_and_different_instances_for_all_trees)
print("average_time_sufficient_reason_for_all_trees_after_correction,std_cumultative time_sufficient_reason and temps_avg_elapsed_time_sufficient_reason_for_all_trees_after_correction",average_elapsed_time_sufficient_reason_for_all_trees_after_correction,std_time_sufficient_reason,temps_avg_elapsed_time_sufficient_reason_for_all_trees_after_correction)
print("average_time_compilation,std_time_compilation,time_compilation",average_time_compilation,std_time_compilation,time_compilation)
# Out:
# average_time_sufficient_reason_for_all_trees_after_correction,std_cumultative time_sufficient_reason and temps_avg_elapsed_time_sufficient_reason_for_all_trees_after_correction 0.5508333299160004 0.2250942757668564 [0.309385302066803, 0.5684780693054199, 0.2649527597427368, 0.42362950801849364, 0.7887561273574829, 0.4776010799407959, 0.43801584482192996, 0.5235971450805664, 0.9922816038131714, 0.7216358590126037]
# average_time_compilation,std_time_compilation,time_compilation 22.849948787689208 4.142655854040425 [21.676039934158325, 24.207911729812622, 14.526028871536255, 20.95039939880371, 21.640163898468018, 20.709704160690308, 21.84265685081482, 26.582464933395386, 28.673476219177246, 27.6906418800354]

# %%
# dictionnaire time x_reason
#"These data are retrieved directly from the xreason logs in the following directory: xreason/xreason/src/results/mx/.
dataset_times = {
 11.648, 1.942, 5.834, 5.332, 12.936, 8.332, 8.169, 10.807, 1.996, 7.418, 10.397, 7.643, 8.623, 7.744, 9.999, 11.369, 11.077, 7.528, 7.810, 7.850, 9.117, 13.046, 13.860, 9.493, 9.126, 12.567, 6.639, 12.462, 11.510, 11.968, 14.328, 10.929, 8.296, 15.002, 16.931, 10.326, 26.869, 12.064, 11.797, 9.969, 14.488, 13.030, 2.979, 11.478, 11.331, 21.652, 18.094, 16.422, 12.566, 13.558, 13.850, 16.022, 6.567],

}

# %%
import matplotlib.pyplot as plt
import numpy as np

def compute_curve(times):
    sorted_times = sorted(times)
    n = len(sorted_times)
    x = [0] + sorted_times                   # on ajoute t=0 au début
    y = [n] + [n - i for i in range(1, n + 1)]  # au début toutes les instances sont non résolues
    return x, y


# Exemple avec deux jeux de données déjà définis
# x1, y1 = compute_curve(dataset_times[dataset])
x2, y2 = compute_curve(mean_size)

# Plot
plt.figure(figsize=(6,4))
# plt.step(x1, y1, where="post", label="P")
plt.step(x2, y2, where="post", label="I")

plt.xlabel("Times")
plt.ylabel("Number of unresolved instances")
#plt.title("Cumulative curves of remaining instances")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()

# Sauvegarde en PNG avec haute résolution
plt.savefig("unresolved instances_"+dataset +"_cumulative_curves.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def compute_curve(times):
    sorted_times = sorted(times)
    n = len(sorted_times)
    x = [0] + sorted_times                   # on ajoute t=0 au début
    y = [n] + [n - i for i in range(1, n + 1)]  # au début toutes les instances sont non résolues
    return x, y


# Exemple avec deux jeux de données déjà définis
x1, y1 = compute_curve(dataset_times[dataset])
# x2, y2 = compute_curve(mean_size)

# Plot
plt.figure(figsize=(6,4))
plt.step(x1, y1, where="post", label="P")
# plt.step(x2, y2, where="post", label="I")

plt.xlabel("Times")
plt.ylabel("Number of unresolved instances")
#plt.title("Cumulative curves of remaining instances")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()

# Sauvegarde en PNG avec haute résolution
plt.savefig("unresolved instances_"+dataset +"_cumulative_curves.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def compute_curve(times):
    sorted_times = sorted(times)
    n = len(sorted_times)
    x = [0] + sorted_times                   # on ajoute t=0 au début
    y = [n] + [n - i for i in range(1, n + 1)]  # au début toutes les instances sont non résolues
    return x, y


# Exemple avec deux jeux de données
x1, y1 = compute_curve(dataset_times[dataset])  # pour P
x2, y2 = compute_curve(mean_size)              # pour I

# Création d'une figure avec 2 sous-graphiques (un au-dessus de l'autre)
fig, axs = plt.subplots(2, 1, figsize=(6, 8))

# Premier graphe (P) avec xlim [0,180]
axs[0].step(x1, y1, where="post", color="blue", label="P")
# axs[0].set_xlim(0, 180)
axs[0].set_ylabel("Unresolved instances")
axs[0].grid(True, linestyle="--", alpha=0.6)
axs[0].legend()

# Deuxième graphe (I) avec xlim [0,1]
axs[1].step(x2, y2, where="post", color="red", label="I")
# axs[1].set_xlim(0, 1)
axs[1].set_xlabel("Times")
axs[1].set_ylabel("Unresolved instances")
axs[1].grid(True, linestyle="--", alpha=0.6)
axs[1].legend()

# Ajuster les espacements
plt.tight_layout()

# Sauvegarde en PNG
plt.savefig("unresolved_instances_"+dataset+"_two_curves.png", dpi=300, bbox_inches="tight")

plt.show()
